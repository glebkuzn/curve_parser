# %%
from src.utils import get_points
import plotly.express as px
import seaborn as sns

# %%
df=get_points('img/graph2.jpg',
                          x_col_name="time",
                          y_col_name="Mau",
                           x_min_value=4.1, 
                           x_max_value=7.6, 
                           y_min_value=0.0, 
                           y_max_value=1.9
                           )

# %%
df.to_csv('./data/graph2.csv', sep=';', index=False)

# %%
sns.lineplot(df, x=df.columns[0], y=df.columns[1], label='Хроматограмма')
# Out:
# <Axes: xlabel='time', ylabel='Mau'>

# %%
fig = px.line(df, x=df.columns[0], y=df.columns[1], title='Хроматограмма')
fig.show()

# %%
df['Mau'].max()
# Out:
# 1.4915887850467289
